# %%
with open('C:\\Users\sanket agarwal\Downloads\Datasets\\README.txt', 'r') as data:
  plaintext = data.read()

plaintext = plaintext.replace(',', '')

# %%
with open('C:\\Users\sanket agarwal\Downloads\Datasets\\README.txt', 'w') as data:
    data.write(plaintext)

# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\sanket agarwal\Downloads\Datasets\\NEW_README.txt",sep="\t",names=['Region Name','NAME','LINK'])

# %%
df
# Out:
#               Region Name             NAME  \
# 0   # ML-Workshop-II-Year              NaN
# 1            REGISTRATION             NAME
# 2              pce17cs144      Satya Singh
# 3              PCE17CS160     Tanuj Sharma
# 4              PCE17CS070    Himanshu Garg
# 5              PCE17CS089   KULDEEP TAILOR
# 6              PCE17CS018   Alfaij Mansuri
# 7              pce17cs143   sanket agarwal
# 8              PCE17CS160     Tanuj Sharma
# 9              PCE17CS084    KARTIK PANDEY
# 10             PCE17CS161     Tarun Sharma
# 11             PCE17CS026  Ankush Pokharna
# 12             PCE17CS028   Anushka Tiwari
# 13             PCE17CS030       Arya Sinha
# 14             PCE17CS001     Aakansha kow
# 15             PCE17CS069    Hemant Sharma
# 16             Pce17cs120   Prayas vastava
# 17             PCE17CS119     Praveen Kuma
# 18             PCE17CS027  Anubhav vastava
# 19             PCE17CS165  Utkarsh Shringi
#
# ...
